# %% [markdown]
# Hi Peter,
#
# # Weg 1
#
# also die Aufgabentellungn ist simpel. Ich will Ein Bild mit einer Kamera aufnehmen und sie mit opencv facerec wiedergeben.
# Um die facel recognition musst du dir keinen kopf machen. facecascader ... läuft.
#
# Das Problem ist es soll auf unserer embedded Hardware laufen. Dort hab ich python3, openCV 4.1, QT5 und gstreamer.
#
# Im ersten Anlauf will ich einfach das bild mittels gstreamer anzeigen.
# Ich hab folgenden code (python) gefunden bei dem ein gstreamer 'appsrc' erzeugt wird. Um daten in die gstreamer pipeline zu bekommen.
#
# meine Frage ist, wie läuft das jetzt genau?
# wie erfährt gstreamer von dem appsrc? Baue ich eine bash in der erst die python Funktion läuft und dann gstreamer aufgerufen wird? Aber eigentlich muss das doch parallel laufen, denn der stream soll ja durchgehend laufen?
#
# weisst du wie man das schreibt, also den gstreamer befehl um die daten parallel aufzunehmen?
# Da ich sicherlich keine gstremer python bindings habe kann ich das also nicht direkt in pthon integrieren... Jihaa
#
#
# Eigentlich hab ich noch 10000 Fragen, aber ich glaube die haubt frage ist:
# Wie zeige ich ein Bild von openCV aus Python mittels gstreamer (oder QT5).
#
#
# ps. die kammera wird mit li4vi initialisiert und

# %%
import cv2

cap = cv2.VideoCapture(0)

framerate = 25.0

out = cv2.VideoWriter('appsrc ! videoconvert ! '
                      'x264enc noise-reduction=10000 speed-preset=ultrafast tune=zerolatency ! '
                      'rtph264pay config-interval=1 pt=96 !'
                      'tcpserversink host=192.168.1.27 port=5000 sync=false',
                      0, framerate, (640, 480))

while cap.isOpened():
    ret, frame = cap.read()
    if ret:

        out.write(frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release everything if job is finished
cap.release()
out.release()

# %% [markdown]
# # Weg 2
#
# Einfach das openCV facedetection cpp beispiel nehmen und laufen lassen (https://docs.opencv.org/4.1.0/d4/d26/samples_2cpp_2facedetect_8cpp-example.html).
#
# ich muss das dann aber glaube ich für arm64 compalieren. Korrekt? Kannst du mir vielleicht sagen wie das geht?
#
# Oder kann ich das einfach als cpp speichern und dann auf dem device aufrufen... hört sich für mich nicht korrekt an?
#
# Merci
